# %% [markdown]
# # More Pandas

# %% [markdown]
# ![panda](http://res.freestockphotos.biz/thumbs/3/3173-illustration-of-a-giant-panda-eating-bamboo-th.png)

# %% [markdown]
# Suppose you were interested in opening an animal shelter. To inform your planning, it would be useful to analyze data from other shelters to understand their operations. In this lecture, we'll analyze animal outcome data from the Austin Animal Center.

# %% [markdown]
# ## Objectives
#
# - Apply and use `.map()`, `apply()`, and `.applymap()` from the `pandas` library
# - Apply and use `.where()` and `.select()` from the `numpy` library
# - Use lambda functions in coordination with the above functions
# - Explain what a groupby object is and split a DataFrame using `.groupby()`

# %%
import numpy as np
import pandas as pd
import requests
from matplotlib import pyplot as plt

# %matplotlib inline

# These next lines ensure that the notebook
# stays current with respect to active .py files.
# See here:
# https://ipython.org/ipython-doc/3/config/extensions/autoreload.html

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Loading the Data
#
# Let's take a moment to download and to examine the [Austin Animal Center data set](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Outcomes/9t4d-g238/data).
#
# We can also ingest the data right off the web, as we do below. The code below will load data for the last 1000 animals to leave the center.

# %%
url = 'https://data.austintexas.gov/resource/9t4d-g238.json'
response = requests.get(url)
animals = pd.DataFrame(response.json())

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# Exploring a new dataset is essential for understanding what it contains. This will generate ideas for processing the data and questions to try to answer in futher analysis.

# %% [markdown]
# ## Inspecting the Data
#
# Let's take a look at a few rows of data.

# %%
animals.head()
# Out:
#   animal_id                 datetime                monthyear  \
# 0   A829195  2021-02-08T13:26:00.000  2021-02-08T13:26:00.000
# 1   A829112  2021-02-07T18:46:00.000  2021-02-07T18:46:00.000
# 2   A825378  2021-02-07T17:44:00.000  2021-02-07T17:44:00.000
# 3   A828450  2021-02-07T17:42:00.000  2021-02-07T17:42:00.000
# 4   A829121  2021-02-07T17:40:00.000  2021-02-07T17:40:00.000
#
#              date_of_birth outcome_type outcome_subtype animal_type  \
# 0  2019-02-04T00:00:00.000   Euthanasia       Suffering         Cat
# 1  2020-11-17T00:00:00.000     Transfer         Partner         Dog
# 2  2016-11-02T00:00:00.000     Adoption             NaN         Dog
# 3  2020-01-16T00:00:00.000     Adoption             NaN         Dog
# 4  2020-10-02T00:00:00.000     Adoption             NaN         Dog
#
#   sex_upon_outcome age_upon_outcome                   breed  \
# 0      Intact Male          2 years      Domestic Shorthair
# 1    Intact Female         2 months                Pit Bull
# 2    Spayed Female          4 years  Labrador Retriever Mix
# 3    Neutered Male           1 year                Pit Bull
# 4    Intact Female         4 months           Catahoula Mix
#
#                  color      name
# 0         Orange Tabby       NaN
# 1  Brown Brindle/White       NaN
# 2          Black/White  Tita Tot
# 3          White/Black    Domino
# 4     Blue Merle/Black       NaN

# %% [markdown]
# The `info()` and `describe()` provide a useful overview of the data.

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   animal_id         1000 non-null   object
#  1   datetime          1000 non-null   object
#  2   monthyear         1000 non-null   object
#  3   date_of_birth     1000 non-null   object
#  4   outcome_type      991 non-null    object
#  5   outcome_subtype   545 non-null    object
#  6   animal_type       1000 non-null   object
#  7   sex_upon_outcome  1000 non-null   object
#  8   age_upon_outcome  1000 non-null   object
#  9   breed             1000 non-null   object
#  10  color             1000 non-null   object
#  11  name              729 non-null    object
# dtypes: object(12)
# memory usage: 93.9+ KB

# %%
animals.describe()
# Out:
#        animal_id                 datetime                monthyear  \
# count       1000                     1000                     1000
# unique       971                      906                      906
# top      A828197  2021-01-30T17:15:00.000  2021-01-30T17:15:00.000
# freq           3                        6                        6
#
#                   date_of_birth outcome_type outcome_subtype animal_type  \
# count                      1000          991             545        1000
# unique                      560            8              10           4
# top     2020-10-26T00:00:00.000     Adoption          Foster         Dog
# freq                         13          540             247         575
#
#        sex_upon_outcome age_upon_outcome               breed        color name
# count              1000             1000                1000         1000  729
# unique                5               32                 195          112  630
# top       Neutered Male          2 years  Domestic Shorthair  Black/White  Max
# freq                415              209                 215          113    9

# %%
# Use value counts to check a categorical feature's distribution

animals['color'].value_counts()
# Out:
# Black/White           113
# Black                  75
# Brown Tabby            67
# White                  43
# Brown/White            43
#                      ...
# White/Orange Tabby      1
# Tortie/Tortie           1
# Blue/Brown Brindle      1
# Calico/Brown Tabby      1
# Red/Tan                 1
# Name: color, Length: 112, dtype: int64

# %% [markdown]
# Now that we have a sense of the data available to us, we can focus in on some more specific questions to dig into. These questions may or may not be directly relevant to your goal (e.g. helping plan a new shelter), but will always help you gain a better understanding of your data.
#
# In your EDA notebooks, **markdown** will be especially helpful in tracking these questions and your methods of answering the questions.

# %% [markdown]
# ## Question 1: What animal types are in the dataset?

# %% [markdown]
# We can then begin thinking about what parts of the DataFrame we need to answer the question.
#
#     What features do we need?
#      - "animal_type"
#     What type of logic and calculation do we perform?
#      - Let's use `.value_counts()` to count the different animal types
#     What type of visualization would help us answer the question?
#      - A bar chart would be good for this purpose

# %%
animals['animal_type'].value_counts()
# Out:
# Dog      575
# Cat      361
# Other     55
# Bird       9
# Name: animal_type, dtype: int64

# %%
fig, ax = plt.subplots()

ax.barh(animals['animal_type'].value_counts().index,
        width=animals['animal_type'].value_counts().values)
ax.set_xlabel('count');

# %%
animals['animal_type'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Questions lead to other questions. For the above example, the visualization raises the question...
#
# ## Question 2: What "Other" animals are in the dataset?
#
# To find out, we need to know whether the type of animal for "Other" is in our dataset - and if so, where to find it.
#
# **Discussion**: Where might we look to find animal types within the Other category?
#
# <details>
#     <summary>
#         Answer
#     </summary>
#         The breed column.
# </details>

# %%
# Your exploration here

# %% [markdown]
# Let's use that column to answer our question.

# %%
animals[animals['animal_type'] == 'Other']['breed'].value_counts()
# Out:
# Hamster         16
# Bat             13
# Raccoon          7
# Fox              6
# Guinea Pig       5
# Skunk            3
# Rabbit Sh        3
# Lop-Mini Mix     1
# Lizard           1
# Name: breed, dtype: int64

# %% [markdown]
# ## Question 3: How old are the animals in our dataset?
#
# Let's try to answer this with the `age_upon_outcome` variable to learn some new `pandas` tools.

# %%
animals['age_upon_outcome'].value_counts()
# Out:
# 2 years      209
# 1 year       167
# 2 months      96
# 3 years       69
# 4 months      54
# 3 months      53
# 6 months      38
# 5 months      31
# 4 years       29
# 1 month       28
# 5 years       26
# 8 months      23
# 10 months     21
# 8 years       20
# 10 years      17
# 7 years       17
# 6 years       17
# 7 months      13
# 9 years       11
# 9 months       9
# 11 months      9
# 12 years       8
# 2 days         7
# 13 years       7
# 11 years       6
# 14 years       4
# 2 weeks        3
# 1 weeks        3
# 4 weeks        2
# 15 years       1
# NULL           1
# 20 years       1
# Name: age_upon_outcome, dtype: int64

# %% [markdown]
# ### `Series.map()` and `Series.apply()`
#
# The `.map()` method applies a transformation to every entry in the Series. This transformation  "maps" each value from the Series to a new value. A transformation can be defined by a function, Series, or dictionary - usually we'll use functions.
#
# The `.apply()` method is similar to the `.map()` method for Series, but can only use functions. It has more powerful uses when working with DataFrames.

# %%
def one_year(age):
    if age == '1 year':
        return '1 years'
    else:
        return age

# %%
animals['new_age1'] = animals['age_upon_outcome'].map(one_year)
animals['new_age1'].value_counts()
# Out:
# 2 years      209
# 1 years      167
# 2 months      96
# 3 years       69
# 4 months      54
# 3 months      53
# 6 months      38
# 5 months      31
# 4 years       29
# 1 month       28
# 5 years       26
# 8 months      23
# 10 months     21
# 8 years       20
# 6 years       17
# 10 years      17
# 7 years       17
# 7 months      13
# 9 years       11
# 11 months      9
# 9 months       9
# 12 years       8
# 13 years       7
# 2 days         7
# 11 years       6
# 14 years       4
# 1 weeks        3
# 2 weeks        3
# 4 weeks        2
# 20 years       1
# NULL           1
# 15 years       1
# Name: new_age1, dtype: int64

# %% [markdown]
# ### Slower Than `numpy`
#
# In general, `np.where()` and `np.select()` are faster:

# %%
animals['new_age2'] = np.where(animals['age_upon_outcome'] == '1 year',
                              '1 years', animals['age_upon_outcome'])
animals['new_age2']
# Out:
# 0       2 years
# 1      2 months
# 2       4 years
# 3       1 years
# 4      4 months
#          ...
# 995     2 years
# 996    5 months
# 997     1 years
# 998     2 years
# 999    2 months
# Name: new_age2, Length: 1000, dtype: object

# %%
(animals['new_age1'] != animals['new_age2']).sum()
# Out:
# 0

# %%
# %timeit animals['new_age1'] = animals['age_upon_outcome'].map(one_year)
# Out:
# 209 µs ± 5.01 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit animals['new_age2'] = np.where(animals['age_upon_outcome'] == '1 year', \
                              '1 years', animals['age_upon_outcome'])
# Out:
# 158 µs ± 1.67 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# ### More Sophisticated Mapping
#
# Let's use `.map()` to turn sex_upon_outcome into a category with three values (called **ternary**): male, female, or unknown.
#
# First, explore the unique values:

# %%
animals['sex_upon_outcome'].unique()
# Out:
# array(['Intact Male', 'Intact Female', 'Spayed Female', 'Neutered Male',
#        'Unknown'], dtype=object)

# %%
def sex_mapper(status):
    if status in ['Neutered Male', 'Intact Male']:
        return 'Male'
    elif status in ['Spayed Female', 'Intact Female']:
        return 'Female'
    else:
        return 'Unknown'

# %%
animals['new_sex1'] = animals['sex_upon_outcome'].map(sex_mapper)
animals['new_sex1']
# Out:
# 0        Male
# 1      Female
# 2      Female
# 3        Male
# 4      Female
#         ...
# 995    Female
# 996    Female
# 997      Male
# 998    Female
# 999    Female
# Name: new_sex1, Length: 1000, dtype: object

# %% [markdown]
# Again, `numpy` will be faster:

# %%
conditions = [animals['sex_upon_outcome'] == 'Neutered Male',
             animals['sex_upon_outcome'] == 'Intact Male',
             animals['sex_upon_outcome'] == 'Spayed Female',
             animals['sex_upon_outcome'] == 'Intact Female',
             animals['sex_upon_outcome'] == 'Unknown',
             animals['sex_upon_outcome'] == 'NULL']

choices = ['Male', 'Male', 'Female', 'Female', 'Unknown', 'Unknown']

# %%
animals['new_sex2'] = np.select(conditions, choices)
animals['new_sex2']
# Out:
# 0        Male
# 1      Female
# 2      Female
# 3        Male
# 4      Female
#         ...
# 995    Female
# 996    Female
# 997      Male
# 998    Female
# 999    Female
# Name: new_sex2, Length: 1000, dtype: object

# %%
(animals['new_sex1'] != animals['new_sex2']).sum()
# Out:
# 0

# %%
# %timeit animals['new_sex1'] = animals['sex_upon_outcome'].map(sex_mapper)
# Out:
# 245 µs ± 3.82 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit animals['new_sex2'] = np.select(conditions, choices)
# Out:
# 182 µs ± 1.62 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# ### Lambda Functions

# %% [markdown]
# Simple functions can be defined just when you need them, when you would call the function. These are called **lambda functions**. These functions are **anonymous** and disappear immediately after use.

# %% [markdown]
# Let's use a lambda function to get rid of 'Other' in the "animal_type' column.

# %%
animals[animals['animal_type'] == 'Other']
# Out:
#     animal_id                 datetime                monthyear  \
# 9     A829221  2021-02-07T09:10:00.000  2021-02-07T09:10:00.000
# 43    A829212  2021-02-05T08:03:00.000  2021-02-05T08:03:00.000
# 69    A829194  2021-02-04T10:51:00.000  2021-02-04T10:51:00.000
# 96    A829138  2021-02-03T08:46:00.000  2021-02-03T08:46:00.000
# 110   A828912  2021-02-02T13:17:00.000  2021-02-02T13:17:00.000
# 153   A828913  2021-01-31T09:20:00.000  2021-01-31T09:20:00.000
# 164   A828640  2021-01-30T16:35:00.000  2021-01-30T16:35:00.000
# 204   A828945  2021-01-29T14:37:00.000  2021-01-29T14:37:00.000
# 223   A828742  2021-01-28T14:57:00.000  2021-01-28T14:57:00.000
# 241   A828889  2021-01-28T10:36:00.000  2021-01-28T10:36:00.000
# 242   A828849  2021-01-28T08:11:00.000  2021-01-28T08:11:00.000
# 243   A828880  2021-01-28T08:09:00.000  2021-01-28T08:09:00.000
# 244   A828850  2021-01-28T08:08:00.000  2021-01-28T08:08:00.000
# 282   A828039  2021-01-27T09:15:00.000  2021-01-27T09:15:00.000
# 284   A828834  2021-01-27T08:58:00.000  2021-01-27T08:58:00.000
# 291   A828531  2021-01-26T17:05:00.000  2021-01-26T17:05:00.000
# 292   A828530  2021-01-26T17:04:00.000  2021-01-26T17:04:00.000
# 340   A828692  2021-01-24T07:53:00.000  2021-01-24T07:53:00.000
# 395   A828564  2021-01-21T12:15:00.000  2021-01-21T12:15:00.000
# 429   A828429  2021-01-20T09:10:00.000  2021-01-20T09:10:00.000
# 430   A828492  2021-01-20T09:08:00.000  2021-01-20T09:08:00.000
# 444   A828043  2021-01-19T14:01:00.000  2021-01-19T14:01:00.000
# 477   A828428  2021-01-17T10:46:00.000  2021-01-17T10:46:00.000
# 515   A828379  2021-01-15T09:36:00.000  2021-01-15T09:36:00.000
# 529   A827955  2021-01-14T09:36:00.000  2021-01-14T09:36:00.000
# 530   A828307  2021-01-14T09:16:00.000  2021-01-14T09:16:00.000
# 549   A828179  2021-01-13T10:36:00.000  2021-01-13T10:36:00.000
# 570   A828073  2021-01-12T12:37:00.000  2021-01-12T12:37:00.000
# 598   A828187  2021-01-11T09:36:00.000  2021-01-11T09:36:00.000
# 599   A828037  2021-01-10T12:35:00.000  2021-01-10T12:35:00.000
# 614   A828044  2021-01-09T07:02:00.000  2021-01-09T07:02:00.000
# 615   A828036  2021-01-09T04:00:00.000  2021-01-09T04:00:00.000
# 639   A828116  2021-01-08T09:44:00.000  2021-01-08T09:44:00.000
# 659   A827627  2021-01-07T12:36:00.000  2021-01-07T12:36:00.000
# 676   A827615  2021-01-07T09:56:00.000  2021-01-07T09:56:00.000
# 677   A827614  2021-01-07T09:56:00.000  2021-01-07T09:56:00.000
# 678   A828051  2021-01-07T09:55:00.000  2021-01-07T09:55:00.000
# 679   A828053  2021-01-07T09:54:00.000  2021-01-07T09:54:00.000
# 680   A828052  2021-01-07T09:54:00.000  2021-01-07T09:54:00.000
# 681   A828054  2021-01-07T09:54:00.000  2021-01-07T09:54:00.000
# 682   A828055  2021-01-07T09:54:00.000  2021-01-07T09:54:00.000
# 683   A828057  2021-01-07T09:53:00.000  2021-01-07T09:53:00.000
# 684   A828056  2021-01-07T09:53:00.000  2021-01-07T09:53:00.000
# 685   A828041  2021-01-07T09:53:00.000  2021-01-07T09:53:00.000
# 686   A828042  2021-01-07T09:53:00.000  2021-01-07T09:53:00.000
# 687   A828040  2021-01-07T09:52:00.000  2021-01-07T09:52:00.000
# 688   A828038  2021-01-07T09:52:00.000  2021-01-07T09:52:00.000
# 738   A827968  2021-01-04T17:50:00.000  2021-01-04T17:50:00.000
# 747   A827909  2021-01-03T16:39:00.000  2021-01-03T16:39:00.000
# 757   A827862  2021-01-03T10:29:00.000  2021-01-03T10:29:00.000
# 795   A827673  2020-12-31T18:34:00.000  2020-12-31T18:34:00.000
# 815   A827499  2020-12-31T10:57:00.000  2020-12-31T10:57:00.000
# 816   A827739  2020-12-31T09:49:00.000  2020-12-31T09:49:00.000
# 923   A827560  2020-12-26T08:06:00.000  2020-12-26T08:06:00.000
# 929   A827530  2020-12-24T12:24:00.000  2020-12-24T12:24:00.000
#
#                date_of_birth outcome_type outcome_subtype animal_type  \
# 9    2019-02-04T00:00:00.000   Euthanasia     Rabies Risk       Other
# 43   2019-02-04T00:00:00.000   Euthanasia     Rabies Risk       Other
# 69   2020-02-04T00:00:00.000     Disposal             NaN       Other
# 96   2020-02-02T00:00:00.000   Euthanasia     Rabies Risk       Other
# 110  2019-01-28T00:00:00.000   Euthanasia     Rabies Risk       Other
# 153  2019-01-28T00:00:00.000   Euthanasia     Rabies Risk       Other
# 164  2020-06-22T00:00:00.000     Adoption          Foster       Other
# 204  2020-08-29T00:00:00.000   Euthanasia     Rabies Risk       Other
# 223  2019-01-26T00:00:00.000     Transfer         Partner       Other
# 241  2020-01-28T00:00:00.000   Euthanasia       Suffering       Other
# 242  2020-01-27T00:00:00.000   Euthanasia     Rabies Risk       Other
# 243  2019-01-27T00:00:00.000   Euthanasia     Rabies Risk       Other
# 244  2020-01-27T00:00:00.000   Euthanasia     Rabies Risk       Other
# 282  2020-10-06T00:00:00.000     Adoption          Foster       Other
# 284  2020-01-27T00:00:00.000   Euthanasia     Rabies Risk       Other
# 291  2020-01-19T00:00:00.000     Adoption             NaN       Other
# 292  2020-01-19T00:00:00.000     Adoption             NaN       Other
# 340  2020-01-24T00:00:00.000   Euthanasia     Rabies Risk       Other
# 395  2020-01-20T00:00:00.000   Euthanasia             NaN       Other
# 429  2019-01-16T00:00:00.000     Disposal             NaN       Other
# 430  2019-01-18T00:00:00.000   Euthanasia       Suffering       Other
# 444  2020-10-06T00:00:00.000      Missing       In Kennel       Other
# 477  2020-01-16T00:00:00.000   Euthanasia     Rabies Risk       Other
# 515  2020-01-15T00:00:00.000   Euthanasia     Rabies Risk       Other
# 529  2019-01-04T00:00:00.000     Adoption             NaN       Other
# 530  2019-01-13T00:00:00.000     Disposal             NaN       Other
# 549  2020-01-09T00:00:00.000   Euthanasia       Suffering       Other
# 570  2020-01-06T00:00:00.000     Adoption             NaN       Other
# 598  2020-01-10T00:00:00.000     Disposal             NaN       Other
# 599  2020-01-05T00:00:00.000     Adoption          Foster       Other
# 614  2020-10-06T00:00:00.000     Adoption          Foster       Other
# 615  2020-10-06T00:00:00.000      Missing       In Kennel       Other
# 639  2020-01-08T00:00:00.000   Euthanasia     Rabies Risk       Other
# 659  2018-12-28T00:00:00.000     Adoption             NaN       Other
# 676  2019-12-27T00:00:00.000     Transfer         Partner       Other
# 677  2019-12-27T00:00:00.000     Transfer         Partner       Other
# 678  2021-01-05T00:00:00.000     Transfer         Partner       Other
# 679  2021-01-05T00:00:00.000     Transfer         Partner       Other
# 680  2021-01-05T00:00:00.000     Transfer         Partner       Other
# 681  2021-01-05T00:00:00.000     Transfer         Partner       Other
# 682  2021-01-05T00:00:00.000     Transfer         Partner       Other
# 683  2021-01-05T00:00:00.000     Transfer         Partner       Other
# 684  2021-01-05T00:00:00.000     Transfer         Partner       Other
# 685  2020-10-06T00:00:00.000     Transfer         Partner       Other
# 686  2020-01-05T00:00:00.000     Transfer         Partner       Other
# 687  2020-10-06T00:00:00.000     Transfer         Partner       Other
# 688  2020-10-06T00:00:00.000     Transfer         Partner       Other
# 738  2019-01-04T00:00:00.000   Euthanasia     Rabies Risk       Other
# 747  2020-01-03T00:00:00.000   Euthanasia     Rabies Risk       Other
# 757  2020-01-02T00:00:00.000   Euthanasia     Rabies Risk       Other
# 795  2019-12-28T00:00:00.000   Euthanasia     Rabies Risk       Other
# 815  2020-09-23T00:00:00.000     Adoption             NaN       Other
# 816  2018-12-30T00:00:00.000   Euthanasia     Rabies Risk       Other
# 923  2018-12-24T00:00:00.000   Euthanasia          At Vet       Other
# 929  2018-12-23T00:00:00.000   Euthanasia     Rabies Risk       Other
#
#     sex_upon_outcome age_upon_outcome         breed           color  \
# 9            Unknown          2 years           Bat     Brown/Brown
# 43           Unknown          2 years           Bat     Brown/Brown
# 69           Unknown           1 year           Bat           Black
# 96           Unknown           1 year           Bat           Brown
# 110          Unknown          2 years           Bat     Brown/Brown
# 153          Unknown          2 years           Bat     Brown/Brown
# 164          Unknown         7 months  Lop-Mini Mix           Sable
# 204          Unknown         5 months         Skunk     Black/White
# 223      Intact Male          2 years        Lizard           Brown
# 241          Unknown           1 year       Raccoon      Black/Gray
# 242          Unknown           1 year           Bat           Black
# 243          Unknown          2 years           Bat     Brown/Brown
# 244          Unknown           1 year           Bat           Black
# 282      Intact Male         3 months       Hamster             Tan
# 284          Unknown           1 year           Bat           Black
# 291    Neutered Male           1 year    Guinea Pig        Tricolor
# 292    Intact Female           1 year    Guinea Pig       Tan/White
# 340          Unknown           1 year           Bat           Black
# 395          Unknown           1 year       Raccoon      Gray/Black
# 429          Unknown          2 years           Fox        Gray/Tan
# 430          Unknown          2 years           Fox             Red
# 444      Intact Male         3 months       Hamster           White
# 477          Unknown           1 year       Raccoon      Black/Gray
# 515          Unknown           1 year         Skunk     Black/White
# 529      Intact Male          2 years     Rabbit Sh             Tan
# 530          Unknown          2 years           Fox             Red
# 549          Unknown           1 year       Raccoon      Black/Gray
# 570      Intact Male           1 year     Rabbit Sh     Black/White
# 598          Unknown           1 year           Fox      Gray/Brown
# 599      Intact Male           1 year       Hamster           White
# 614      Intact Male         3 months       Hamster             Tan
# 615      Intact Male         3 months       Hamster           White
# 639          Unknown           1 year           Fox     Brown/Black
# 659      Intact Male          2 years     Rabbit Sh   Brown Brindle
# 676      Intact Male           1 year    Guinea Pig           White
# 677      Intact Male           1 year    Guinea Pig        Tricolor
# 678          Unknown           2 days       Hamster             Tan
# 679          Unknown           2 days       Hamster             Tan
# 680          Unknown           2 days       Hamster             Tan
# 681          Unknown           2 days       Hamster             Tan
# 682          Unknown           2 days       Hamster             Tan
# 683          Unknown           2 days       Hamster             Tan
# 684          Unknown           2 days       Hamster             Tan
# 685    Intact Female         3 months       Hamster           White
# 686    Intact Female           1 year       Hamster           White
# 687    Intact Female         3 months       Hamster             Tan
# 688    Intact Female         3 months       Hamster           White
# 738          Unknown          2 years           Bat           Brown
# 747          Unknown           1 year           Bat           Brown
# 757          Unknown           1 year       Raccoon      Black/Gray
# 795          Unknown           1 year       Raccoon      Black/Gray
# 815          Unknown         3 months    Guinea Pig  White/Tricolor
# 816          Unknown          2 years         Skunk           Black
# 923          Unknown          2 years           Fox            Gray
# 929          Unknown          2 years       Raccoon           Brown
#
#            name  new_age1  new_age2 new_sex1 new_sex2
# 9           NaN   2 years   2 years  Unknown  Unknown
# 43          NaN   2 years   2 years  Unknown  Unknown
# 69          NaN   1 years   1 years  Unknown  Unknown
# 96          NaN   1 years   1 years  Unknown  Unknown
# 110         NaN   2 years   2 years  Unknown  Unknown
# 153         NaN   2 years   2 years  Unknown  Unknown
# 164     Blossom  7 months  7 months  Unknown  Unknown
# 204         NaN  5 months  5 months  Unknown  Unknown
# 223         NaN   2 years   2 years     Male     Male
# 241         NaN   1 years   1 years  Unknown  Unknown
# 242         NaN   1 years   1 years  Unknown  Unknown
# 243         NaN   2 years   2 years  Unknown  Unknown
# 244         NaN   1 years   1 years  Unknown  Unknown
# 282    *Hamtaro  3 months  3 months     Male     Male
# 284         NaN   1 years   1 years  Unknown  Unknown
# 291        *Roy   1 years   1 years     Male     Male
# 292  *Siegfried   1 years   1 years   Female   Female
# 340         NaN   1 years   1 years  Unknown  Unknown
# 395         NaN   1 years   1 years  Unknown  Unknown
# 429         NaN   2 years   2 years  Unknown  Unknown
# 430         NaN   2 years   2 years  Unknown  Unknown
# 444         NaN  3 months  3 months     Male     Male
# 477         NaN   1 years   1 years  Unknown  Unknown
# 515         NaN   1 years   1 years  Unknown  Unknown
# 529    *Cheerio   2 years   2 years     Male     Male
# 530         NaN   2 years   2 years  Unknown  Unknown
# 549         NaN   1 years   1 years  Unknown  Unknown
# 570     *Ernest   1 years   1 years     Male     Male
# 598         NaN   1 years   1 years  Unknown  Unknown
# 599         NaN   1 years   1 years     Male     Male
# 614         NaN  3 months  3 months     Male     Male
# 615         NaN  3 months  3 months     Male     Male
# 639         NaN   1 years   1 years  Unknown  Unknown
# 659         NaN   2 years   2 years     Male     Male
# 676    *Schmidt   1 years   1 years     Male     Male
# 677    *Winston   1 years   1 years     Male     Male
# 678         NaN    2 days    2 days  Unknown  Unknown
# 679         NaN    2 days    2 days  Unknown  Unknown
# 680         NaN    2 days    2 days  Unknown  Unknown
# 681         NaN    2 days    2 days  Unknown  Unknown
# 682         NaN    2 days    2 days  Unknown  Unknown
# 683         NaN    2 days    2 days  Unknown  Unknown
# 684         NaN    2 days    2 days  Unknown  Unknown
# 685         NaN  3 months  3 months   Female   Female
# 686         NaN   1 years   1 years   Female   Female
# 687         NaN  3 months  3 months   Female   Female
# 688         NaN  3 months  3 months   Female   Female
# 738         NaN   2 years   2 years  Unknown  Unknown
# 747         NaN   1 years   1 years  Unknown  Unknown
# 757         NaN   1 years   1 years  Unknown  Unknown
# 795         NaN   1 years   1 years  Unknown  Unknown
# 815          Cc  3 months  3 months  Unknown  Unknown
# 816         NaN   2 years   2 years  Unknown  Unknown
# 923         NaN   2 years   2 years  Unknown  Unknown
# 929         NaN   2 years   2 years  Unknown  Unknown

# %%
animals['animal_type'].value_counts()
# Out:
# Dog      575
# Cat      361
# Other     55
# Bird       9
# Name: animal_type, dtype: int64

# %%
animals['animal_type'].map(lambda x: np.nan if x == 'Other' else x).value_counts()
# Out:
# Dog     575
# Cat     361
# Bird      9
# Name: animal_type, dtype: int64

# %% [markdown]
# ## Methods for Re-Organizing DataFrames: `.groupby()`

# %% [markdown]
# The `.groupby()` method lets you group together subsets of data so you can apply functions to groups.
#
# It is most useful when we have numeric data that we want to **aggregate**, meaning that we want to combine multiple observations together into a new, summary observation.
#
# Let's create a numeric variable by turning "age_upon_outcome" into a number of days.
#
# This method is similar to the GROUP BY statement in SQL, which we'll discuss soon.

# %%
animals['age_split'] = animals['new_age1'].str.split(" ")
animals['age_split']
# Out:
# 0       [2, years]
# 1      [2, months]
# 2       [4, years]
# 3       [1, years]
# 4      [4, months]
#           ...
# 995     [2, years]
# 996    [5, months]
# 997     [1, years]
# 998     [2, years]
# 999    [2, months]
# Name: age_split, Length: 1000, dtype: object

# %%
def count_days(x):
    """
    This function will convert ages into numbers of days.
    """
    if x[-1] == 'days':
        return int(x[0])
    elif x[-1] == 'weeks':
        return int(x[0]) * 7
    elif x[-1] == 'months':
        return int(x[0]) * 30
    elif x[-1] == 'years':
        return int(x[0]) * 365
    else:
        return np.nan

# %%
animals['age_days'] = animals['age_split'].map(count_days).astype(float)
animals['age_days']
# Out:
# 0       730.0
# 1        60.0
# 2      1460.0
# 3       365.0
# 4       120.0
#         ...
# 995     730.0
# 996     150.0
# 997     365.0
# 998     730.0
# 999      60.0
# Name: age_days, Length: 1000, dtype: float64

# %%
animals.groupby('animal_type').mean()
# Out:
#                age_days
# animal_type
# Bird         405.555556
# Cat          711.031250
# Dog          929.533333
# Other        371.618182

# %% [markdown]
# Notice the object type [DataFrameGroupBy](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html) object.

# %%
type(animals.groupby('animal_type'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# ### .groups and .get_group()

# %%
# This retuns a dictionary with each group 
# indexed by the group name, along with the 
# row indices for each animal in the group.

animals.groupby('animal_type').groups
# Out:
# {'Bird': [449, 450, 633, 634, 635, 838, 839, 840, 930], 'Cat': [0, 13, 14, 17, 20, 24, 25, 26, 33, 36, 39, 46, 47, 56, 66, 67, 68, 71, 72, 73, 74, 76, 77, 83, 85, 86, 88, 89, 95, 98, 104, 106, 111, 112, 118, 119, 120, 121, 122, 125, 126, 127, 128, 129, 131, 140, 141, 152, 154, 155, 156, 157, 158, 159, 160, 161, 162, 165, 172, 177, 180, 187, 188, 197, 199, 202, 205, 206, 209, 211, 212, 213, 215, 218, 220, 224, 226, 229, 247, 250, 252, 254, 255, 256, 261, 262, 263, 264, 269, 273, 275, 277, 280, 281, 283, 286, 287, 288, 289, 294, ...], 'Dog': [1, 2, 3, 4, 5, 6, 7, 8, 10, 11, 12, 15, 16, 18, 19, 21, 22, 23, 27, 28, 29, 30, 31, 32, 34, 35, 37, 38, 40, 41, 42, 44, 45, 48, 49, 50, 51, 52, 53, 54, 55, 57, 58, 59, 60, 61, 62, 63, 64, 65, 70, 75, 78, 79, 80, 81, 82, 84, 87, 90, 91, 92, 93, 94, 97, 99, 100, 101, 102, 103, 105, 107, 108, 109, 113, 114, 115, 116, 117, 123, 124, 130, 132, 133, 134, 135, 136, 137, 138, 139, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, ...], 'Other': [9, 43, 69, 96, 110, 153, 164, 204, 223, 241, 242, 243, 244, 282, 284, 291, 292, 340, 395, 429, 430, 444, 477, 515, 529, 530, 549, 570, 598, 599, 614, 615, 639, 659, 676, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687, 688, 738, 747, 757, 795, 815, 816, 923, 929]}

# %%
animals.groupby('animal_type').get_group('Dog')
# Out:
#     animal_id                 datetime                monthyear  \
# 1     A829112  2021-02-07T18:46:00.000  2021-02-07T18:46:00.000
# 2     A825378  2021-02-07T17:44:00.000  2021-02-07T17:44:00.000
# 3     A828450  2021-02-07T17:42:00.000  2021-02-07T17:42:00.000
# 4     A829121  2021-02-07T17:40:00.000  2021-02-07T17:40:00.000
# 5     A829183  2021-02-07T16:52:00.000  2021-02-07T16:52:00.000
# ..        ...                      ...                      ...
# 993   A827212  2020-12-21T17:28:00.000  2020-12-21T17:28:00.000
# 995   A827280  2020-12-21T17:22:00.000  2020-12-21T17:22:00.000
# 996   A827258  2020-12-21T17:04:00.000  2020-12-21T17:04:00.000
# 997   A827368  2020-12-21T16:56:00.000  2020-12-21T16:56:00.000
# 998   A827164  2020-12-21T16:55:00.000  2020-12-21T16:55:00.000
#
#                date_of_birth     outcome_type outcome_subtype animal_type  \
# 1    2020-11-17T00:00:00.000         Transfer         Partner         Dog
# 2    2016-11-02T00:00:00.000         Adoption             NaN         Dog
# 3    2020-01-16T00:00:00.000         Adoption             NaN         Dog
# 4    2020-10-02T00:00:00.000         Adoption             NaN         Dog
# 5    2017-02-04T00:00:00.000       Euthanasia       Suffering         Dog
# ..                       ...              ...             ...         ...
# 993  2018-12-16T00:00:00.000         Adoption             NaN         Dog
# 995  2018-12-17T00:00:00.000         Adoption             NaN         Dog
# 996  2020-07-17T00:00:00.000         Adoption             NaN         Dog
# 997  2019-12-01T00:00:00.000  Return to Owner             NaN         Dog
# 998  2018-12-15T00:00:00.000         Adoption             NaN         Dog
#
#     sex_upon_outcome age_upon_outcome                      breed  \
# 1      Intact Female         2 months                   Pit Bull
# 2      Spayed Female          4 years     Labrador Retriever Mix
# 3      Neutered Male           1 year                   Pit Bull
# 4      Intact Female         4 months              Catahoula Mix
# 5      Intact Female          4 years  Maltese/Yorkshire Terrier
# ..               ...              ...                        ...
# 993    Neutered Male          2 years             Siberian Husky
# 995    Spayed Female          2 years        Chihuahua Shorthair
# 996    Spayed Female         5 months            German Shepherd
# 997      Intact Male           1 year            German Shepherd
# 998    Spayed Female          2 years                    Mastiff
#
#                    color          name  new_age1  new_age2 new_sex1 new_sex2  \
# 1    Brown Brindle/White           NaN  2 months  2 months   Female   Female
# 2            Black/White      Tita Tot   4 years   4 years   Female   Female
# 3            White/Black        Domino   1 years   1 years     Male     Male
# 4       Blue Merle/Black           NaN  4 months  4 months   Female   Female
# 5                  Cream         Chica   4 years   4 years   Female   Female
# ..                   ...           ...       ...       ...      ...      ...
# 993            Red/White  *Ol'Mcdonald   2 years   2 years     Male     Male
# 995                  Tan           NaN   2 years   2 years   Female   Female
# 996          Brown/Black           NaN  5 months  5 months   Female   Female
# 997          Brown/Black          Cash   1 years   1 years     Male     Male
# 998        Brown Brindle           NaN   2 years   2 years   Female   Female
#
#        age_split  age_days
# 1    [2, months]      60.0
# 2     [4, years]    1460.0
# 3     [1, years]     365.0
# 4    [4, months]     120.0
# 5     [4, years]    1460.0
# ..           ...       ...
# 993   [2, years]     730.0
# 995   [2, years]     730.0
# 996  [5, months]     150.0
# 997   [1, years]     365.0
# 998   [2, years]     730.0
#
# [575 rows x 18 columns]

# %% [markdown]
# We can group by multiple columns, and also return a DataFrameGroupBy object

# %%
animals.groupby(['animal_type', 'outcome_type'])

# %%
animals.groupby(['animal_type', 'outcome_type']).groups.keys()
# Out:
# dict_keys([('Cat', 'Euthanasia'), ('Dog', 'Transfer'), ('Dog', 'Adoption'), ('Dog', 'Euthanasia'), ('Dog', 'Return to Owner'), ('Other', 'Euthanasia'), ('Cat', 'Transfer'), ('Cat', 'Adoption'), ('Other', 'Disposal'), ('Cat', nan), ('Cat', 'Return to Owner'), ('Dog', nan), ('Dog', 'Rto-Adopt'), ('Dog', 'Disposal'), ('Other', 'Adoption'), ('Cat', 'Disposal'), ('Cat', 'Rto-Adopt'), ('Other', 'Transfer'), ('Dog', 'Died'), ('Cat', 'Died'), ('Other', 'Missing'), ('Bird', 'Adoption'), ('Bird', 'Transfer'), ('Bird', 'Died')])

# %%
# We can then get a specific group, such as cats that were adopted

animals.groupby(['animal_type', 'outcome_type']).get_group(('Cat', 'Adoption'))
# Out:
#     animal_id                 datetime                monthyear  \
# 14    A828615  2021-02-06T14:30:00.000  2021-02-06T14:30:00.000
# 17    A828026  2021-02-06T12:49:00.000  2021-02-06T12:49:00.000
# 20    A829050  2021-02-06T11:50:00.000  2021-02-06T11:50:00.000
# 36    A821320  2021-02-05T12:17:00.000  2021-02-05T12:17:00.000
# 46    A823024  2021-02-04T17:25:00.000  2021-02-04T17:25:00.000
# ..        ...                      ...                      ...
# 986   A825934  2020-12-22T07:27:00.000  2020-12-22T07:27:00.000
# 988   A823534  2020-12-22T00:00:00.000  2020-12-22T00:00:00.000
# 991   A826834  2020-12-21T17:55:00.000  2020-12-21T17:55:00.000
# 994   A827319  2020-12-21T17:25:00.000  2020-12-21T17:25:00.000
# 999   A827166  2020-12-21T16:53:00.000  2020-12-21T16:53:00.000
#
#                date_of_birth outcome_type outcome_subtype animal_type  \
# 14   2019-01-21T00:00:00.000     Adoption             NaN         Cat
# 17   2020-01-05T00:00:00.000     Adoption          Foster         Cat
# 20   2013-02-01T00:00:00.000     Adoption          Foster         Cat
# 36   2020-08-06T00:00:00.000     Adoption          Foster         Cat
# 46   2020-08-21T00:00:00.000     Adoption             NaN         Cat
# ..                       ...          ...             ...         ...
# 986  2020-09-24T00:00:00.000     Adoption          Foster         Cat
# 988  2020-08-10T00:00:00.000     Adoption          Foster         Cat
# 991  2020-09-24T00:00:00.000     Adoption             NaN         Cat
# 994  2020-06-18T00:00:00.000     Adoption             NaN         Cat
# 999  2020-10-20T00:00:00.000     Adoption             NaN         Cat
#
#     sex_upon_outcome age_upon_outcome                   breed  \
# 14     Spayed Female          2 years      Domestic Shorthair
# 17     Neutered Male           1 year      Domestic Shorthair
# 20     Neutered Male          8 years      Domestic Shorthair
# 36     Neutered Male         6 months      Domestic Shorthair
# 46     Spayed Female         5 months  Domestic Shorthair Mix
# ..               ...              ...                     ...
# 986    Spayed Female         2 months      Domestic Shorthair
# 988    Neutered Male         4 months      Domestic Shorthair
# 991    Spayed Female         2 months      Domestic Shorthair
# 994    Neutered Male         6 months  Domestic Shorthair Mix
# 999    Spayed Female         2 months      Domestic Shorthair
#
#                  color       name  new_age1  new_age2 new_sex1 new_sex2  \
# 14          Blue Tabby    Thunder   2 years   2 years   Female   Female
# 17         Brown Tabby     *Simon   1 years   1 years     Male     Male
# 20               White     *Kirby   8 years   8 years     Male     Male
# 36          White/Blue      *Inky  6 months  6 months     Male     Male
# 46         Brown Tabby   Magnolia  5 months  5 months   Female   Female
# ..                 ...        ...       ...       ...      ...      ...
# 986        Black/White    *Barada  2 months  2 months   Female   Female
# 988  White/Cream Tabby  *Habanero  4 months  4 months     Male     Male
# 991             Calico        NaN  2 months  2 months   Female   Female
# 994        Brown Tabby      Wally  6 months  6 months     Male     Male
# 999             Torbie        NaN  2 months  2 months   Female   Female
#
#        age_split  age_days
# 14    [2, years]     730.0
# 17    [1, years]     365.0
# 20    [8, years]    2920.0
# 36   [6, months]     180.0
# 46   [5, months]     150.0
# ..           ...       ...
# 986  [2, months]      60.0
# 988  [4, months]     120.0
# 991  [2, months]      60.0
# 994  [6, months]     180.0
# 999  [2, months]      60.0
#
# [229 rows x 18 columns]

# %% [markdown]
# ## Aggregating

# %%
# Just like with single axis groups, we can aggregate on multiple axes

animals.groupby(['animal_type', 'outcome_type']).mean()
# Out:
#                                 age_days
# animal_type outcome_type
# Bird        Adoption          365.000000
#             Died              730.000000
#             Transfer          365.000000
# Cat         Adoption          516.031390
#             Died              150.000000
#             Disposal          365.000000
#             Euthanasia       1439.444444
#             Return to Owner  1019.333333
#             Rto-Adopt        1054.166667
#             Transfer         1035.343750
# Dog         Adoption          737.491409
#             Died              120.000000
#             Disposal           60.000000
#             Euthanasia       1241.000000
#             Return to Owner  1393.790323
#             Rto-Adopt        1137.857143
#             Transfer          894.447368
# Other       Adoption          340.000000
#             Disposal          547.500000
#             Euthanasia        502.400000
#             Missing            90.000000
#             Transfer          150.642857

# %% [markdown]
# ## `.agg()`
#
# Use the `.agg()` method to specify in more detail the variables you want to aggregate and the aggregation functions you want to use.

# %%
animals.groupby(['animal_type', 'outcome_type']).agg({'age_days': ['mean', 'max']})
# Out:
#                                 age_days
#                                     mean     max
# animal_type outcome_type
# Bird        Adoption          365.000000   365.0
#             Died              730.000000   730.0
#             Transfer          365.000000   365.0
# Cat         Adoption          516.031390  5110.0
#             Died              150.000000   150.0
#             Disposal          365.000000   365.0
#             Euthanasia       1439.444444  4380.0
#             Return to Owner  1019.333333  5475.0
#             Rto-Adopt        1054.166667  2555.0
#             Transfer         1035.343750  4745.0
# Dog         Adoption          737.491409  5110.0
#             Died              120.000000   120.0
#             Disposal           60.000000    60.0
#             Euthanasia       1241.000000  4015.0
#             Return to Owner  1393.790323  7300.0
#             Rto-Adopt        1137.857143  3650.0
#             Transfer          894.447368  5110.0
# Other       Adoption          340.000000   730.0
#             Disposal          547.500000   730.0
#             Euthanasia        502.400000   730.0
#             Missing            90.000000    90.0
#             Transfer          150.642857   730.0

# %% [markdown]
# ## Level Up: `.applymap()`
#
# `.applymap()` is used to apply a transformation to each element of a DataFrame.

# %%
# This line will apply the base `type()` function to 
# all entries of the DataFrame.

animals.applymap(type)
# Out:
#          animal_id       datetime      monthyear  date_of_birth  \
# 0    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 1    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 2    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 3    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 4    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# ..             ...            ...            ...            ...
# 995  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 996  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 997  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 998  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 999  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
#
#       outcome_type  outcome_subtype    animal_type sex_upon_outcome  \
# 0    <class 'str'>    <class 'str'>  <class 'str'>    <class 'str'>
# 1    <class 'str'>    <class 'str'>  <class 'str'>    <class 'str'>
# 2    <class 'str'>  <class 'float'>  <class 'str'>    <class 'str'>
# 3    <class 'str'>  <class 'float'>  <class 'str'>    <class 'str'>
# 4    <class 'str'>  <class 'float'>  <class 'str'>    <class 'str'>
# ..             ...              ...            ...              ...
# 995  <class 'str'>  <class 'float'>  <class 'str'>    <class 'str'>
# 996  <class 'str'>  <class 'float'>  <class 'str'>    <class 'str'>
# 997  <class 'str'>  <class 'float'>  <class 'str'>    <class 'str'>
# 998  <class 'str'>  <class 'float'>  <class 'str'>    <class 'str'>
# 999  <class 'str'>  <class 'float'>  <class 'str'>    <class 'str'>
#
#     age_upon_outcome          breed          color             name  \
# 0      <class 'str'>  <class 'str'>  <class 'str'>  <class 'float'>
# 1      <class 'str'>  <class 'str'>  <class 'str'>  <class 'float'>
# 2      <class 'str'>  <class 'str'>  <class 'str'>    <class 'str'>
# 3      <class 'str'>  <class 'str'>  <class 'str'>    <class 'str'>
# 4      <class 'str'>  <class 'str'>  <class 'str'>  <class 'float'>
# ..               ...            ...            ...              ...
# 995    <class 'str'>  <class 'str'>  <class 'str'>  <class 'float'>
# 996    <class 'str'>  <class 'str'>  <class 'str'>  <class 'float'>
# 997    <class 'str'>  <class 'str'>  <class 'str'>    <class 'str'>
# 998    <class 'str'>  <class 'str'>  <class 'str'>  <class 'float'>
# 999    <class 'str'>  <class 'str'>  <class 'str'>  <class 'float'>
#
#           new_age1       new_age2       new_sex1       new_sex2  \
# 0    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 1    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 2    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 3    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 4    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# ..             ...            ...            ...            ...
# 995  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 996  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 997  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 998  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 999  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
#
#           age_split         age_days
# 0    <class 'list'>  <class 'float'>
# 1    <class 'list'>  <class 'float'>
# 2    <class 'list'>  <class 'float'>
# 3    <class 'list'>  <class 'float'>
# 4    <class 'list'>  <class 'float'>
# ..              ...              ...
# 995  <class 'list'>  <class 'float'>
# 996  <class 'list'>  <class 'float'>
# 997  <class 'list'>  <class 'float'>
# 998  <class 'list'>  <class 'float'>
# 999  <class 'list'>  <class 'float'>
#
# [1000 rows x 18 columns]
